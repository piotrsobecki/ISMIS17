# %%
from commons import *
from extractors import *

# %%
t_train = pd.DataFrame.from_csv(trainTransformed,index_col=None)

# %%
t_train.head()
# Out:
#    TransID   SymbolID  Decision  ExpertID  Prediction      Rate  TimeBefore
# 0      0.0  S94311056        -1      3084           1  0.460372           0
# 1      0.0  S94311056        -1      3864           1  0.186413           6
# 2      0.0  S94311056        -1     25525           1  0.211129           7
# 3      0.0  S94311056        -1       342           1  0.165861           9
# 4      0.0  S94311056        -1      1573           1  0.251586           9

# %%
experts = Extractor().extract_experts(t_train)
# Out:
# E:\Anaconda2\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\Anaconda2\lib\site-packages\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)

# %%
experts
# Out:
#       ExpertID     Buy_p     Buy_r  Buy_n    Hold_p    Hold_r  Hold_n  Sell_p  \
# 0        208.0  0.000000  0.000000    5.0  0.000000  0.000000     2.0   0.125
# 1        209.0  0.666667  0.571429    7.0  0.000000  0.000000     2.0   0.000
# 2        221.0  0.403509  1.000000   23.0  1.000000  0.095238    21.0   0.000
# 3        222.0  0.477273  0.913043   23.0  0.428571  0.187500    16.0   0.000
# 4        223.0  0.500000  0.875000    8.0  0.500000  0.166667     6.0   0.000
# 5        224.0  0.423077  0.916667   12.0  0.600000  0.230769    13.0   0.000
# 6        227.0  0.428571  0.500000    6.0  0.142857  0.333333     3.0   0.000
# 7        229.0  0.000000  0.000000    0.0  0.000000  0.000000     1.0   0.000
# 8        230.0  0.750000  1.000000    3.0  0.000000  0.000000     1.0   0.000
# 9        231.0  1.000000  0.400000    5.0  0.000000  0.000000     0.0   0.000
# 10       232.0  1.000000  0.333333    3.0  0.333333  1.000000     1.0   0.000
# ...

# %%
experts.to_csv("experts.csv",index=False)
